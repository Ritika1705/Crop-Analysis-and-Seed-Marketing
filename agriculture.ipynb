# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import os
from sklearn import metrics

# %%
df={}
d=[]
dataset=pd.read_csv('agri .csv')

# %%
dataset.head()
# Out:
#                     State_Name District_Name  Crop_Year  Season  Temperature  \
# 0  Andaman and Nicobar Islands      NICOBARS       2010  Autumn        30.19
# 1  Andaman and Nicobar Islands      NICOBARS       2010  Autumn        31.74
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif        30.26
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Kharif        29.66
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Kharif        30.79
#
#    Avg Rainfall                 Crop    Area  Production
# 0        352.49                 Rice     3.5       10.00
# 1        353.09            Sugarcane    13.4       41.75
# 2        101.48             Arecanut  1254.0     2000.00
# 3        102.16  Other Kharif pulses     2.0        1.00
# 4        104.51                 Rice   102.0      321.00

# %%
for i in dataset['District_Name'].unique():
    d.append(i)
    
m=0
i=0    

while(i<len(d)):
    n=0
    for j in range(m,990):
        if(dataset.iloc[j,1]==d[i]):
            df[i]=pd.DataFrame(dataset.iloc[j-n:j+1,:])
            n=n+1
            m=m+1
    i=i+1

# %%
x=df[0].iloc[:,[3,4,5]].values
y=df[0].iloc[:,6].values
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_x=LabelEncoder()
labelencoder_y=LabelEncoder()
x[:,0]=labelencoder_x.fit_transform(x[:,0])
onehotencoder=OneHotEncoder(categorical_features=[0])
x=onehotencoder.fit_transform(x).toarray()
y=labelencoder_y.fit_transform(y)
# Out:
# /home/mansi/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/mansi/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
for i in range(len(df)):  
    
      x=df[i].iloc[:,[3,4,5]].values
      y=df[i].iloc[:,6].values
      
 
   


      from sklearn.preprocessing import LabelEncoder,OneHotEncoder
      labelencoder_x=LabelEncoder()
      labelencoder_y=LabelEncoder()
      x[:,0]=labelencoder_x.fit_transform(x[:,0])
      onehotencoder=OneHotEncoder(categorical_features=[0])
      x=onehotencoder.fit_transform(x).toarray()
      y=labelencoder_y.fit_transform(y)
      

      x=x[:,1:]
    
     
    
      from sklearn.model_selection import train_test_split
      x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
         
      from sklearn.preprocessing import StandardScaler
      sc_x = StandardScaler()
      x_train = sc_x.fit_transform(x_train)
      x_test = sc_x.transform(x_test)
      sc_y = StandardScaler()
      y_train=y_train.reshape(-1,1)
      y_train = sc_y.fit_transform(y_train)


        
      from sklearn.linear_model import LinearRegression
      regressor = LinearRegression()
      #from sklearn.ensemble import RandomForestRegressor
      #regressor = RandomForestRegressor(n_estimators=100)
      regressor.fit(x_train, y_train)

      y_pred=regressor.predict(x_test)
      from sklearn.metrics import mean_squared_error
      from math import sqrt
      mse1=round((mean_squared_error(y_test,y_pred))/100, 2)
      rmse1 = round((sqrt(mse1))/100 ,2)
      print(mse1 )
      print(rmse1)


      import statsmodels.regression.linear_model as sm
      def backwardElimination(x, sl):
         numVars = len(x[0])
         for i in range(0, numVars):
             regressor_OLS = sm.OLS(y, x).fit()
             maxVar = max(regressor_OLS.pvalues).astype(float)
             if maxVar > sl:
                 for j in range(0, numVars - i):
                     if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                         x = np.delete(x, j, 1)
         regressor_OLS.summary()
         return x
 
      SL = 0.90
      x_opt = x[:, :]
      x_Modeled = backwardElimination(x_opt, SL)
      
      x1=x[:,-2:] 

      from sklearn.model_selection import train_test_split
      x_train1,x_test1,y_train,y_test=train_test_split(x1,y,test_size=0.25,random_state=0)
      from sklearn.linear_model import LinearRegression
      regressor=LinearRegression()
      regressor.fit(x_train1,y_train)

      y_pred1=regressor.predict(x_test1)
      y_pred1=y_pred1.astype(int)
      y_pred2=labelencoder_y.inverse_transform(y_pred1)
      

      from sklearn.metrics import mean_squared_error
      from math import sqrt
      mse2=round((mean_squared_error(y_test,y_pred))/100, 2)
      rmse2 = round((sqrt(mse2))/100 ,2)
      print(mse2) 
      print(rmse2)

      print(metrics.mean_absolute_error(y_test, y_pred1))
      print(metrics.mean_squared_error(y_test, y_pred1))
      print(np.sqrt(metrics.mean_squared_error(y_test, y_pred1)))
#print(df[0])

      metrics.explained_variance_score(y_test, y_pred1)		
      metrics.mean_absolute_error(y_test, y_pred1)	
      metrics.median_absolute_error(y_test, y_pred1)
   

      plt.plot(y_pred1,x_test1[:,-2],color='blue')
      plt.plot(y_test,x_test1[:,-2],color='red')
      plt.show()

      plt.scatter(y_pred1,x_test1[:,-2],color='blue')   
      plt.scatter(y_test,x_test1[:,-2],color='red') 
      plt.show()
#fakegen(9,22,1.5,1554)
# Out:
# 0.67
# 0.01
# 0.67
# 0.01
# 3.55
# 24.35
# 4.934571916590131
# /home/mansi/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/mansi/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ...

# %%
mse1

# %%
rmse1

# %%
mse2

# %%
rmse2

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
print("Length of dataframe= ",len(df[0]))
print("Length of train x= ",len(x_train))
print("Length of train y= ",len(y_train))
print("Length of test x= ",len(x_test))
print("Length of test y= ",len(y_test))
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)
sc_y = StandardScaler()
y_train=y_train.reshape(-1,1)
y_train = sc_y.fit_transform(y_train)
# Out:
# Length of dataframe=  79
# Length of train x=  59
# Length of train y=  59
# Length of test x=  20
# Length of test y=  20

# %%
''''from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=250)
trained_model=regressor.fit(x_train, y_train)
train_accuracy_score = trained_model.score(x_train,y_train)
print("Training accuracy is= ",round(train_accuracy_score * 100, 2), "%")'''
# Out:
# Training accuracy is=  82.15 %

# %%
test_model=regressor.fit(x_test, y_test)
test_accuracy_score = test_model.score(x_test,y_test)
print("Test accuracy is= ",round(test_accuracy_score * 100, 2), "%")
# Out:
# Test accuracy is=  80.22 %

# %%
print(x_Modeled)
# Out:
# [[  0.     0.     0.    30.19 352.49]
#  [  0.     0.     0.    31.74 353.09]
#  [  1.     0.     0.    30.26 101.48]
#  [  1.     0.     0.    29.66 102.16]
#  [  1.     0.     0.    30.79 104.51]
#  [  1.     0.     0.    27.7  102.96]
#  [  1.     0.     0.    27.25 104.37]
#  [  1.     0.     0.    27.76 104.04]
#  [  1.     0.     0.    26.87 102.73]
#  [  1.     0.     0.    28.4  104.01]
#  [  1.     0.     0.    29.75 102.07]
#  [  1.     0.     0.    28.71 101.88]
#  [  0.     1.     0.    34.49  97.  ]
#  [  0.     1.     0.    35.4   97.  ]
#  [  0.     1.     0.    34.72  97.  ]
#  [  0.     1.     0.    34.75  97.  ]
#  [  0.     1.     0.    34.55  97.  ]
#  [  0.     1.     0.    31.9   97.  ]
#  [  0.     1.     0.    31.82  97.  ]
#  [  0.     1.     0.    30.79  97.  ]
#  [  0.     1.     0.    29.88  97.  ]
#  [  0.     1.     0.    29.    97.  ]
#  [  0.     0.     1.    32.73 255.  ]
#  [  0.     0.     1.    34.88 255.  ]
#  [  0.     0.     1.    33.69 255.  ]
# ...

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
mse=round((mean_squared_error(y_test,y_pred))/100, 2)
rmse = round((sqrt(mse1))/100 ,2)
print("Mean Squared Error= ",mse )
print("Root Mean Square Error= ",rmse)
# Out:
# Mean Squared Error=  0.67
# Root Mean Square Error=  0.01

# %%
x_new=pd.DataFrame(x1)

# %%
x_new.head()
# Out:
#        0       1
# 0  30.79  101.96
# 1  29.58  100.01
# 2  31.39  100.72
# 3  29.61  102.28
# 4  29.40  102.86
