# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Data Preprocessing
dataset = pd.read_csv('seedmarket .csv', header = None)
transactions = []
for i in range(0, 47):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 16)])

# %%
# Training Apriori on the dataset
from apyori import apriori
rules = apriori(transactions, min_support = 0.28, min_confidence = 0.56, min_lift = 2, min_length = 5)

# %%
# Visualising the results
results = list(rules)
print(len(results))
print(results[0])
# Out:
# 26
# RelationRecord(items=frozenset({'Jowar', 'Bajra'}), support=0.2978723404255319, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bajra'}), items_add=frozenset({'Jowar'}), confidence=1.0, lift=3.357142857142857), OrderedStatistic(items_base=frozenset({'Jowar'}), items_add=frozenset({'Bajra'}), confidence=1.0, lift=3.357142857142857)])

# %%
for item in results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Bajra -> Jowar
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Rice -> Bajra
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Bajra -> Sesamum
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Rice -> Jowar
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Jowar -> Sesamum
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Urad -> Moong(Green Gram)
# Support: 0.44680851063829785
# Confidence: 1.0
# Lift: 2.1363636363636362
# =====================================
# Rule: Rice -> Sesamum
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Bajra -> Jowar
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Rice -> Bajra
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Bajra -> Jowar
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Rice -> Bajra
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Bajra -> Maize
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Rice -> Bajra
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Rice -> Jowar
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Jowar -> Maize
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Rice -> Jowar
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Urad -> Moong(Green Gram)
# Support: 0.44680851063829785
# Confidence: 1.0
# Lift: 2.1363636363636362
# =====================================
# Rule: Rice -> Maize
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Urad -> Moong(Green Gram)
# Support: 0.3829787234042553
# Confidence: 1.0
# Lift: 2.1363636363636362
# =====================================
# Rule: Rice -> Bajra
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Bajra -> Jowar
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Rice -> Bajra
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Rice -> Bajra
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Rice -> Jowar
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================
# Rule: Urad -> Moong(Green Gram)
# Support: 0.3829787234042553
# Confidence: 1.0
# Lift: 2.1363636363636362
# =====================================
# Rule: Rice -> Bajra
# Support: 0.2978723404255319
# Confidence: 1.0
# Lift: 3.357142857142857
# =====================================

# %%
dataset.head()
# Out:
#           0          1             2          3         4                  5   \
# 0  Arhar/Tur      Bajra     Groundnut      Jowar     Maize  Moong(Green Gram)
# 1  Arhar/Tur      Bajra  Cotton(lint)  Groundnut     Jowar              Maize
# 2  Arhar/Tur      Bajra     Groundnut      Jowar     Maize  Moong(Green Gram)
# 3      Bajra  Groundnut         Jowar      Maize      Rice           Sannhamp
# 4      Bajra      Jowar         Maize       Rice  Sannhamp            Sesamum
#
#                   6              7         8          9     10   11   12   13  \
# 0               Rice        Sesamum  Soyabean       Urad   NaN  NaN  NaN  NaN
# 1  Moong(Green Gram)           Rice   Sesamum   Soyabean  Urad  NaN  NaN  NaN
# 2               Rice        Sesamum  Soyabean  Sunflower  Urad  NaN  NaN  NaN
# 3            Sesamum  Small millets  Soyabean  Sugarcane   NaN  NaN  NaN  NaN
# 4           Soyabean      Sugarcane       NaN        NaN   NaN  NaN  NaN  NaN
#
#     14   15
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
